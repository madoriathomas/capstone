# %% [markdown]
# # News Headline EDA

# %%
# importing all my dependancies
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import nltk
from nltk.probability import FreqDist
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import regexp_tokenize, word_tokenize, RegexpTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix
import string
import re
from sklearn.metrics import ConfusionMatrixDisplay

# %%
corpus = pd.read_csv('data/labeled_newscatcher_dataset.csv', sep=";")
corpus.shape
# Out:
# (108774, 6)

# %%
corpus.head()
# Out:
#      topic                                               link          domain  \
# 0  SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...  eurekalert.org
# 1  SCIENCE  https://www.pulse.ng/news/world/an-irresistibl...        pulse.ng
# 2  SCIENCE  https://www.express.co.uk/news/science/1322607...   express.co.uk
# 3  SCIENCE  https://www.ndtv.com/world-news/glaciers-could...        ndtv.com
# 4  SCIENCE  https://www.thesun.ie/tech/5742187/perseid-met...       thesun.ie
#
#         published_date                                              title lang
# 0  2020-08-06 13:59:45  A closer look at water-splitting's solar fuel ...   en
# 1  2020-08-12 15:14:19  An irresistible scent makes locusts swarm, stu...   en
# 2  2020-08-13 21:01:00  Artificial intelligence warning: AI will know ...   en
# 3  2020-08-03 22:18:26   Glaciers Could Have Sculpted Mars Valleys: Study   en
# 4  2020-08-12 19:54:36  Perseid meteor shower 2020: What time and how ...   en

# %%
# checking for nulls
corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108774 entries, 0 to 108773
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   topic           108774 non-null  object
#  1   link            108774 non-null  object
#  2   domain          108774 non-null  object
#  3   published_date  108774 non-null  object
#  4   title           108774 non-null  object
#  5   lang            108774 non-null  object
# dtypes: object(6)
# memory usage: 5.0+ MB

# %%
# As we can see here, the Science topic has only a third of the news stories compared to the other topics
# The class imbalance could cause an issue later 
corpus['topic'].value_counts()
# Out:
# BUSINESS         15000
# HEALTH           15000
# ENTERTAINMENT    15000
# WORLD            15000
# NATION           15000
# SPORTS           15000
# TECHNOLOGY       15000
# SCIENCE           3774
# Name: topic, dtype: int64

# %%
# checking the language of all the data (although not always accurate)
corpus['lang'].value_counts()
# Out:
# en    108774
# Name: lang, dtype: int64

# %%
# checking out the titles
corpus.loc[100].title
# Out:
# 'Insect can escape after being eaten by frog, scientists find'

# %% [markdown]
# ## Data Cleaning and EDA

# %%
# cleaning my test data
sw = stopwords.words('english')

corpus.title = [word.lower() for word in corpus.title]
pattern = "([a-zA-Z]+(?:'[a-z]+)?)"
corpus.title = [nltk.regexp_tokenize(line, pattern) for line in corpus.title]
lemma = WordNetLemmatizer()
corpus.title= [[lemma.lemmatize(word) for word in line] for line in corpus.title]
corpus.title = [[word for word in line if word not in sw] for line in corpus.title]

# %%
corpus.title
# Out:
# 0         [closer, look, water, splitting's, solar, fuel...
# 1         [irresistible, scent, make, locust, swarm, stu...
# 2         [artificial, intelligence, warning, ai, know, ...
# 3            [glacier, could, sculpted, mar, valley, study]
# 4         [perseid, meteor, shower, time, see, huge, bri...
#                                 ...
# 108769    [pdp, governor, forum, urge, security, agency,...
# 108770    [q, apple, dominated, premium, smartphone, seg...
# 108771    [coronavirus, northern, ireland, full, breakdo...
# 108772    [paul, mccartney, detail, post, beatles, distr...
# 108773    [report, talk, underway, keep, shane, duffy, p...
# Name: title, Length: 108774, dtype: object

# %%
from textblob import TextBlob, Word
from wordcloud import WordCloud

# %%
dict_of_topics = {}

for topic in corpus.topic.unique():
    current_corpus = corpus.loc[corpus['topic'] == topic]
    dict_of_topics[topic] = list(current_corpus.title)

# %%
dict_of_topics
# Out:
# {'SCIENCE': [['closer',
#    'look',
#    'water',
#    "splitting's",
#    'solar',
#    'fuel',
#    'potential'],
#   ['irresistible', 'scent', 'make', 'locust', 'swarm', 'study', 'find'],
#   ['artificial',
#    'intelligence',
#    'warning',
#    'ai',
#    'know',
#    'u',
#    'better',
#    'know'],
#   ['glacier', 'could', 'sculpted', 'mar', 'valley', 'study'],
#   ['perseid',
#    'meteor',
#    'shower',
#    'time',
#    'see',
#    'huge',
#    'bright',
#    'fireball',
#    'uk',
#    'tonight'],
#   ['nasa', 'release', 'depth', 'map', 'beirut', 'explosion', 'damage'],
#   ['spacex', 'nasa', 'demo', 'rocket', 'launch', 'set', 'saturday', 'watch'],
#   ['orbital', 'space', 'tourism', 'set', 'rebirth'],
#   ["greenland's",
#    'melting',
#    'ice',
#    'sheet',
#    'ha',
#    'passed',
#    'point',
#    'return'],
#   ['nasa',
#    'invite',
#    'engineering',
#    'student',
#    'help',
#    'harvest',
#    'water',
#    'mar',
#    'moon'],
#   ['astronomer',
#    'detect',
#    'electromagnetic',
#    'signal',
#    'caused',
#    'unequal',
#    'neutron',
#    'star',
#    'collision'],
#   ['nasa',
#    'find',
#    'ammonia',
#    'linked',
#    'mushballs',
#    'shallow',
#    'lightning',
#    'jupiter'],
#   ['russia', 'target', 'returning', 'venus', 'build', 'reusable', 'rocket'],
#   ['martian', 'night', 'sky', 'pulse', 'ultraviolet', 'light'],
#   ['energy',
#    'efficient',
#    'tuning',
#    'spintronic',
#    'neuron',
#    'imitate',
#    'non',
#    'linear',
#    'oscillatory',
#    'neural',
#    'network',
#    'human',
#    'brain'],
#   ['scientist', 'may', 'discovered', 'achilles', 'heel', 'coronavirus'],
#   ['tradeoff', 'eye', 'nose', 'help', 'fly', 'find', 'niche'],
#   ['final', 'mar', 'mission', 'poised', 'blastoff', 'florida'],
#   ['rare',
#    'find',
#    'fossil',
#    'show',
#    'cretaceous',
#    'era',
#    'hell',
#    'ant',
#    'ate',
#    'prey',
#    'weird',
#    'jaw'],
#   ['nasa', 'spacex', 'crew', 'return', 'dragon', 'capsule', 'splash'],
#   ['take', 'look', 'mar', 'eerie', 'nightglow'],
#   ['cern', 'scientist', 'discover', 'rare', 'higgs', 'boson', 'process'],
#   ['beautiful',
#    'healthy',
#    'young',
#    'woman',
#    'died',
#    'suddenly',
#    'dream',
#    'work',
#    'trip',
#    'australia'],
#   ['hubble',
#    'us',
#    'moon',
#    'mirror',
#    'study',
#    'earth',
#    'atmosphere',
#    'proxy',
#    'search',
#    'potentially',
#    'habitable',
#    'planet',
#    'around',
#    'star'],
#   ['indian', 'researcher', 'show', 'covid', 'ppe', 'turn', 'biofuel'],
#   ['atlantic', 'sky', 'young', 'astronomer', 'perseid', 'meteor'],
#   ['came',
#    'alive',
#    'nasa',
#    'astronaut',
#    'describe',
#    'experiencing',
#    'splashdown',
#    'spacex',
#    'dragon'],
#   ['human', 'find', 'use', 'fire'],
#   ['like',
#    'first',
#    'quarantine',
#    'sourdough',
#    'attempt',
#    'exoplanet',
#    'surprisingly',
#    'dense'],
#   ['ring',
#    'like',
#    'structure',
#    'ganymede',
#    'may',
#    'caused',
#    'violent',
#    'impact'],
#   ['nasa', 'drop', 'insensitive', 'nickname', 'cosmic', 'object'],
#   ['archaeology',
#    'year',
#    'old',
#    'inscription',
#    'jerusalem',
#    'prof',
#    'bible',
#    'right',
#    'expert',
#    'claim'],
#   ['mar', 'helicopter', 'reach', 'big', 'milestone', 'flight', 'planet'],
#   ['sunspot', 'size', 'mar', 'turning', 'towards', 'earth'],
#   ["jupiter's",
#    'huge',
#    'moon',
#    'ganymede',
#    'may',
#    'largest',
#    'impact',
#    'scar',
#    'solar',
#    'system'],
#   ['man',
#    'post',
#    'mind',
#    'blowing',
#    'tiktok',
#    'highest',
#    'point',
#    'canada',
#    'disprove',
#    'flat',
#    'earth',
#    'theory'],
#   ['cause', 'massive', 'fish', 'kill', 'shinnecock', 'canal', 'clear', 'east'],
#   ['unequal',
#    'neutron',
#    'star',
#    'merger',
#    'create',
#    'unique',
#    'bang',
#    'simulation'],
#   ['zombie',
#    'cicada',
#    'influence',
#    'mind',
#    'controlling',
#    'fungus',
#    'returned',
#    'west',
#    'virginia'],
#   ['astronomer',
#    'may',
#    'found',
#    'lost',
#    'neutron',
#    'star',
#    "that's",
#    'missing',
#    'decade'],
#   ["spacex's", 'starship', 'spacecraft', 'saw', 'meter', 'high'],
#   ['orb',
#    'look',
#    'like',
#    'candy',
#    "they're",
#    'actually',
#    'different',
#    'flavour',
#    'phobos'],
#   ['nasa', 'insight', 'lander', 'show', 'beneath', 'mar', 'surface'],
#   ['spacex',
#    'crew',
#    'mission',
#    'nasa',
#    'first',
#    'fully',
#    'operational',
#    'crewed',
#    'mission',
#    'space',
#    'launch',
#    'october'],
#   ['asteroid',
#    'da',
#    'would',
#    'greatest',
#    'catastrophe',
#    'earth',
#    'tsunami',
#    'toe',
#    'excessive',
#    'wave'],
#   ['atlas',
#    'space',
#    'operation',
#    'awarded',
#    'nasa',
#    'sbir',
#    'phase',
#    'ii',
#    'award',
#    'advance',
#    'satellite',
#    'constellation',
#    'management',
#    'scheduling'],
#   ['greenland',
#    'ice',
#    'melting',
#    'irreversible',
#    'ha',
#    'passed',
#    'tipping',
#    'point',
#    'study'],
#   ['nasa', 'astronaut', 'spacex', 'capsule', 'splashdown', 'gulf', 'mexico'],
#   ['alien', 'base', 'mercury', 'et', 'hunter', 'claim', 'find', 'huge', 'ufo'],
#   ["australia's",
#    'small',
#    'yet',
#    'crucial',
#    'part',
#    'mission',
#    'find',
#    'life',
#    'mar'],
#   ['science',
#    'news',
#    'researcher',
#    'suggest',
#    'osmotic',
#    'therapy',
#    'device',
#    'spinal',
#    'cord',
#    'injury'],
#   ['kid',
#    'helpline',
#    'say',
#    'demand',
#    'victoria',
#    'counselling',
#    'service',
#    'rose',
#    'july'],
#   ['russia', 'gearing', 'launch', 'moon', 'mission'],
#   ['insect', 'escape', 'eaten', 'frog', 'scientist', 'find'],
#   ['tonight',
#    'offer',
#    'best',
#    'chance',
#    'spotting',
#    'space',
#    'station',
#    'night',
#    'sky'],
#   ['new', 'guinea', 'named', "world's", 'plant', 'rich', 'island'],
#   ['rachel', 'shenk', 'meteor', 'shower', 'reminder', "nature's", 'beauty'],
#   ['majestic', 'valley', 'mar', 'may', 'carved', 'river'],
#   ['fossilfriday',
#    'amazing',
#    'million',
#    'year',
#    'old',
#    'trilobite',
#    'eye',
#    'saw',
#    'world',
#    'like',
#    'modern',
#    'insect'],
#   ['spacex', 'brings', 'nasa', 'astronaut', 'safely', 'home'],
#   ['covid', 'pose', 'special', 'risk', 'pregnancy', 'hair', 'split', 'steel'],
#   ['perseid', 'meteor', 'shower', 'watch'],
#   ['nasa', 'saved', 'mar', 'mole', 'true'],
#   ['new', 'ct', 'scanning', 'method', 'may', 'improve', 'heart', 'massage'],
#   ['video', 'fire', 'detection', 'work', 'technology', 'equipment'],
#   ['like',
#    'animal',
#    'nasa',
#    'astronaut',
#    'describe',
#    'noisy',
#    'jolting',
#    'descent'],
#   ['eerie', 'full', 'blue', 'moon', 'rise', 'florida', 'halloween', 'night'],
#   ['nasa',
#    'astronaut',
#    'extraordinary',
#    'day',
#    'space',
#    'shoot',
#    'music',
#    'video',
#    'orbit'],
#   ['high',
#    'brightness',
#    'lasing',
#    'submicrometer',
#    'enabled',
#    'droop',
#    'free',
#    'fin',
#    'light',
#    'emitting',
#    'diode',
#    'led'],
#   ['scientist',
#    'use',
#    'earth',
#    'proxy',
#    'detecting',
#    'sign',
#    'life',
#    'exoplanets'],
#   ['nasa', 'administrator', 'statement', 'passing', 'mike', 'freilich'],
#   ['microwaving', 'tea', 'doe', 'ruin', 'cuppa', 'study', 'find'],
#   ['nasa', 'ingenuity', 'mar', 'helicopter', 'recharges', 'battery', 'flight'],
#   ['ur',
#    'receive',
#    'million',
#    'federal',
#    'funding',
#    'new',
#    'physic',
#    'frontier',
#    'center'],
#   ['scientist',
#    'discover',
#    'new',
#    'material',
#    'could',
#    'merge',
#    'ai',
#    'human',
#    'brain'],
#   ['jurassic',
#    'sea',
#    'creature',
#    'spent',
#    'decade',
#    'crossing',
#    'ocean',
#    'raft'],
#   ['jupiter',
#    'storm',
#    'filled',
#    'superbolts',
#    'lightning',
#    'unlike',
#    'anything',
#    'earth'],
#   ['lightning', 'sprite', 'earth'],
#   ['see', 'shooting', 'star', 'week', 'weather', 'wfmz', 'com'],
#   ['astronomical',
#    'first',
#    'difference',
#    'detected',
#    'disc',
#    'active',
#    'non',
#    'active',
#    'galaxy'],
#   ['earth', 'position', 'sustain', 'digital', 'knowledge'],
#   ['year', 'earth', 'receives', 'laser', 'signal', 'moon'],
#   ['team',
#    'international',
#    'physicist',
#    'join',
#    'force',
#    'hunt',
#    'sterile',
#    'neutrino'],
#   ['book',
#    'excerpt',
#    'relentless',
#    'moon',
#    'explores',
#    'challenge',
#    'lunar',
#    'habitation'],
#   ["there's",
#    'still',
#    'chance',
#    'see',
#    'perseid',
#    'meteor',
#    'shower',
#    "here's",
#    'watch'],
#   ['world',
#    'premiere',
#    'researcher',
#    'diagnose',
#    'dinosaur',
#    'malignant',
#    'cancer'],
#   ['august', 'brings', 'perseid', 'meteor', 'shower'],
#   ['astronomer',
#    'find',
#    'milky',
#    'way',
#    'look',
#    'alike',
#    'billion',
#    'light',
#    'year',
#    'away'],
#   ['perseid', 'meteor', 'shower', 'look'],
#   ['classifying', 'galaxy', 'artificial', 'intelligence'],
#   ['perseid',
#    'meteor',
#    'shower',
#    'peak',
#    'tonight',
#    'interesting',
#    'fact',
#    'tip',
#    'spot',
#    "year's",
#    'best',
#    'meteor',
#    'shower',
#    'display'],
#   ['elon',
#    'musk',
#    'spacex',
#    'test',
#    'starship',
#    'aimed',
#    'send',
#    'human',
#    'mar'],
#   ['spacex',
#    'starlink',
#    'satellite',
#    'launch',
#    'cap',
#    'busy',
#    'week',
#    'company',
#    'satellite',
#    'orbit'],
#   ['nasa', 'perseverance', 'prepare', 'oxygen', 'mar'],
#   ['nasa',
#    'postpones',
#    'historic',
#    'spacex',
#    'rocket',
#    'launch',
#    'bad',
#    'weather'],
#   ["nasa's",
#    'osiris',
#    'rex',
#    'one',
#    'rehearsal',
#    'away',
#    'touching',
#    'asteroid',
#    'bennu'],
#   ['gigabyte', 'data', 'examined', 'spacex', 'mission', 'deemed', 'success'],
#   ['nasa',
#    'probe',
#    'prepares',
#    'first',
#    'asteroid',
#    'sample',
#    'collection',
#    'attempt'],
#   ['stellar', 'pulsation', 'distribute', 'key', 'ingredient', 'life'],
#   ['cremation', 'israel', 'date', 'back', 'bc', 'research', 'suggests'],
#   ['secret',
#    "tuatara's",
#    'long',
#    'life',
#    'revealed',
#    "bay's",
#    'news',
#    'first'],
#   ['floppy',
#    'protein',
#    'used',
#    'create',
#    'artificial',
#    'organelle',
#    'within',
#    'human',
#    'cell'],
#   ['spacex', 'nasa', 'rocket', 'visible', 'scotland', 'sky'],
#   ['life',
#    'limit',
#    'microbe',
#    'seabed',
#    'survive',
#    'far',
#    'le',
#    'energy',
#    'shown',
#    'ever'],
#   ['calcium', 'rich', 'supernova', 'examined', 'x', 'ray', 'first', 'time'],
#   ['celebrating', 'story', 'science', 'national', 'science', 'week'],
#   ['closest',
#    'ever',
#    'mysterious',
#    'fast',
#    'radio',
#    'burst',
#    'observed',
#    'light',
#    'several',
#    'year',
#    'earth'],
#   ['new',
#    "zealand's",
#    'glacier',
#    'melting',
#    'twice',
#    'rate',
#    'pre',
#    'industrial',
#    'time'],
#   ['behavior', 'therapeutic', 'antibody', 'immunotherapy'],
#   ['simon',
#    'cowell',
#    'america',
#    'got',
#    'talent',
#    'judge',
#    'suffers',
#    'serious',
#    'back',
#    'injury',
#    'falling'],
#   ['scientist',
#    'create',
#    'material',
#    'make',
#    'salty',
#    'water',
#    'safe',
#    'drink',
#    'minute'],
#   ['iia',
#    'discovers',
#    'enhanced',
#    'cool',
#    'bright',
#    'star',
#    'omega',
#    'centauri'],
#   ['successful',
#    'starship',
#    'hop',
#    'test',
#    'put',
#    'spacex',
#    'one',
#    'step',
#    'closer',
#    'mar'],
#   ['mystery', 'dimming', 'massive', 'star', 'betelgeuse', 'explained'],
#   ['cern', 'say', 'higgs', 'boson', 'something', 'unexpected'],
#   ['spacex', 'sent', 'another', 'starlink', 'satellite', 'skyward'],
#   ['indian', 'scientist', 'make', 'space', 'brick', 'lunar', 'habitation'],
#   ['nasa', 'show', 'impact', 'beirut', 'blast', 'using', 'satellite', 'data'],
#   ["nasa's",
#    'mar',
#    'helicopter',
#    'recharges',
#    'battery',
#    'first',
#    'time',
#    'en',
#    'route',
#    'red',
#    'planet'],
#   ['young',
#    'sub',
#    'neptune',
#    'sized',
#    'planet',
#    'shed',
#    'light',
#    'onto',
#    'planet',
#    'form',
#    'evolve'],
#   ['climate',
#    'scientist',
#    'sound',
#    'alarm',
#    'warming',
#    'greenland',
#    'ice',
#    'sheet',
#    'pass',
#    'point',
#    'return'],
#   ['breakthrough',
#    'technology',
#    'purifies',
#    'water',
#    'using',
#    'power',
#    'sunlight'],
#   ['ecosystem', 'root'],
#   ['photographer',
#    'capture',
#    'eerie',
#    'majestic',
#    'sky',
#    'jellyfish',
#    'storm'],
#   ['spectacular',
#    'shooting',
#    'star',
#    'display',
#    'visible',
#    'dublin',
#    'tonight'],
#   ['researcher',
#    'develop',
#    'technique',
#    'processing',
#    'surface',
#    'atomic',
#    'scale',
#    'phys',
#    'org'],
#   ['prehistoric',
#    'reptile',
#    'long',
#    'neck',
#    'hunting',
#    'underwater',
#    'earth',
#    'com'],
#   ['research',
#    'lab',
#    'creates',
#    'environmentally',
#    'friendly',
#    'flip',
#    'flop',
#    'algae'],
#   ['herbivore', 'vulnerable', 'extinct', 'predator', 'research', 'study'],
#   ['cellulose',
#    'plate',
#    'market',
#    'trend',
#    'size',
#    'forecast',
#    'sigma',
#    'aldrich',
#    'merck',
#    'millipore',
#    'silicycle',
#    'biotage'],
#   ['nasa', 'drop', 'insensitive', 'nickname', 'cosmic', 'object', 'barrie'],
#   ['hell', 'ant', 'found', 'million', 'year', 'old', 'amber'],
#   ['study',
#    'rewrite',
#    'recent',
#    'history',
#    'productive',
#    'cascade',
#    'arc',
#    'volcano'],
#   ['rocket',
#    'report',
#    'south',
#    'korea',
#    'spacex',
#    'dilemma',
#    'rocket',
#    'lab',
#    'find',
#    'quick',
#    'fix'],
#   ["antarctica's",
#    'ice',
#    'melt',
#    'year',
#    'could',
#    'fill',
#    'grand',
#    'canyon',
#    'study'],
#   ['dinosaur',
#    'diagnosed',
#    'malignant',
#    'cancer',
#    'first',
#    'time',
#    'researcher',
#    'say'],
#   ['fossilised',
#    'mln',
#    'year',
#    'old',
#    'eye',
#    'mirror',
#    'modern',
#    'insect',
#    'vision'],
#   ['human', 'ancestor', 'made', 'bed', 'year', 'ago', 'burnt'],
#   ['venus',
#    'ha',
#    'giant',
#    'cloud',
#    'stretching',
#    'thousand',
#    'km',
#    'moving',
#    'kmph'],
#   ['evolutionary',
#    'investigation',
#    'across',
#    'specie',
#    'reveals',
#    'primate',
#    'voice',
#    'box',
#    'evolving',
#    'rapid',
#    'pace'],
#   ['scientist',
#    'probe',
#    'weird',
#    'alien',
#    'water',
#    'inside',
#    'uranus',
#    'neptune'],
#   ['ucalgary',
#    'researcher',
#    'discover',
#    "microbiome's",
#    'role',
#    'attacking',
#    'cancerous',
#    'tumour'],
#   ['year',
#    'curiosity',
#    "nasa's",
#    'mar',
#    'rover',
#    'helped',
#    'u',
#    'know',
#    'red',
#    'planet',
#    'better'],
#   ['came',
#    'alive',
#    'astronaut',
#    'recount',
#    'wild',
#    'ride',
#    'home',
#    "spacex's",
#    'crew',
#    'dragon'],
#   ['scientific',
#    'research',
#    'widen',
#    'spacex',
#    'eye',
#    'commercial',
#    'crew',
#    'mission'],
#   ['fleet',
#    'firefly',
#    'ufo',
#    'spotted',
#    'recent',
#    'live',
#    'feed',
#    'spacex',
#    'starlink',
#    'satellite',
#    'launch'],
#   ['climate',
#    'change',
#    'likely',
#    'cause',
#    'woolly',
#    'rhinoceros',
#    'extinction',
#    'scientist',
#    'say'],
#   ['cold', 'sensitive', 'staphylococci', 'reveal', 'weakness'],
#   ['searching',
#    'ancient',
#    'depth',
#    'reptilian',
#    'genome',
#    'yield',
#    'insight',
#    'vertebrate'],
#   ['arctic',
#    'could',
#    'free',
#    'sea',
#    'ice',
#    'latest',
#    'climate',
#    'model',
#    'predicts'],
#   ['hubble',
#    'find',
#    "betelgeuse's",
#    'mysterious',
#    'dimming',
#    'due',
#    'traumatic',
#    'outburst'],
#   ['outrage',
#    'nasa',
#    'go',
#    'woke',
#    'renames',
#    'insensitive',
#    'space',
#    'object'],
#   ['teeth',
#    'size',
#    'banana',
#    'new',
#    'study',
#    'paint',
#    'picture',
#    'terror',
#    'crocodile'],
#   ['secret',
#    'life',
#    'shark',
#    'study',
#    'reveals',
#    'surprising',
#    'social',
#    'network'],
#   ['black', 'hole', 'caught', 'astronomer', 'wa', 'quitting', 'job'],
#   ['planet',
#    'sized',
#    'sunspot',
#    'confirms',
#    'new',
#    'solar',
#    'cycle',
#    'expect',
#    'killer',
#    'flare'],
#   ['major', 'goal', 'identify', 'planet', 'could', 'support', 'life', 'nasa'],
#   ['spacex',
#    'deploys',
#    'another',
#    'set',
#    'starlink',
#    'satellite',
#    'two',
#    'blacksky',
#    'payload'],
#   ['perseid', 'meteor', 'shower', 'lasting', 'week'],
#   ['hallett', 'cove', 'fossil', 'secret', 'accessible', 'virtual', 'reality'],
#   ['scramble', 'space', 'earth', 'outer', 'limit'],
#   ['ontario', 'doctor', 'subject', 'complaint', 'covid', 'tweet'],
#   ['nasa', 'rocket', 'discovers', 'new', 'structure', 'atmosphere', 'sun'],
#   ['perseid', 'meteor', 'shower', 'peak', 'tuesday', 'watch', 'show'],
#   ['material', 'ultrascaled', 'field', 'effect', 'transistor'],
#   ['land', 'billion', 'face'],
#   ['five',
#    'figure',
#    'funding',
#    'boost',
#    'social',
#    'enterprise',
#    'thebusinessdesk',
#    'com'],
#   ['titanium',
#    'oxide',
#    'nanowire',
#    'based',
#    'air',
#    'channel',
#    'trap',
#    'devastate',
#    'microorganism'],
#   ['rare',
#    'phenomenon',
#    'observed',
#    'atlas',
#    'feature',
#    'lhc',
#    'high',
#    'energy',
#    'photon',
#    'collider'],
#   ['sub',
#    'standard',
#    'weather',
#    'condition',
#    'might',
#    'prevent',
#    'redeployment',
#    'crew',
#    'dragon',
#    'earth'],
#   ['hubble',
#    'us',
#    'earth',
#    'proxy',
#    'identifying',
#    'oxygen',
#    'potentially',
#    'habitable',
#    'exoplanets'],
#   ['glacier', 'new', "zealand's", 'southern', 'alp', 'half', 'gone'],
#   ['let', 'lizard', 'dinosaur'],
#   ['nasa',
#    'astronaut',
#    'aboard',
#    'space',
#    'station',
#    'answer',
#    'stem',
#    'student',
#    'question'],
#   ['broken',
#    'cable',
#    'tear',
#    'foot',
#    'hole',
#    'arecibo',
#    'observatory',
#    'puerto',
#    'rico'],
#   ['nasa', 'data', 'help', 'uncover', 'solar', "system's", 'shape'],
#   ['flight', 'mar', 'cut', 'cosmonaut', 'lifespan', 'year', 'say', 'report'],
#   ['scientist', 'unlock', 'alpine', 'tree', 'molecular', 'defence'],
#   ['scientist',
#    'discover',
#    'star',
#    'rich',
#    'phosphorous',
#    'might',
#    'help',
#    'u',
#    'explain',
#    'origin',
#    'life'],
#   ["nasa's",
#    'ingenuity',
#    'mar',
#    'helicopter',
#    'recharges',
#    'battery',
#    'flight'],
#   ['early',
#    'human',
#    'knew',
#    'make',
#    'comfy',
#    'pest',
#    'free',
#    'bed',
#    'study',
#    'say'],
#   ['canary',
#    'coal',
#    'mine',
#    'greenland',
#    'ice',
#    'ha',
#    'shrunk',
#    'beyond',
#    'return',
#    'study',
#    'find'],
#   ['venus',
#    'new',
#    'full',
#    'moon',
#    'possibly',
#    'best',
#    'meteor',
#    'shower',
#    'sight',
#    'sky',
#    'august'],
#   ['came',
#    'alive',
#    'astronaut',
#    'recount',
#    'wild',
#    'ride',
#    'home',
#    "spacex's",
#    'crew',
#    'dragon'],
#   ['star', 'rich', 'phosphorus', 'seed', 'life', 'universe'],
#   ['football',
#    'field',
#    'sized',
#    'asteroid',
#    'inbound',
#    'today',
#    'another',
#    'footer',
#    'follow',
#    'weekend',
#    'nasa',
#    'warns'],
#   ['solar', 'system', 'protected', 'cosmic', 'radiation'],
#   ['new', 'specie', 'dinosaur', 'discovered', 'isle', 'wight'],
#   ['massive',
#    'sunspot',
#    'heading',
#    'towards',
#    'earth',
#    'cause',
#    'major',
#    'solar',
#    'flare',
#    'need',
#    'know'],
#   ['see',
#    'elon',
#    'musk',
#    'starlink',
#    'satellite',
#    'whizzing',
#    'overhead',
#    'tonight',
#    'billionaire',
#    'launch'],
#   ['new',
#    'usask',
#    'led',
#    'research',
#    'reveals',
#    'previously',
#    'hidden',
#    'feature',
#    'plant',
#    'genome'],
#   ['nasa',
#    'probe',
#    'prepares',
#    'first',
#    'asteroid',
#    'sample',
#    'collection',
#    'attempt'],
#   ['u', 'covid', 'death', 'rise', 'fourth', 'week', 'new', 'case', 'drop'],
#   ['spacex',
#    'success',
#    'pave',
#    'way',
#    'crew',
#    'next',
#    'nasa',
#    'astronaut',
#    'mission'],
#   ['year', 'parent', 'petition', 'course', 'halloween', 'saturday'],
#   ['chernobyl',
#    'fungus',
#    'could',
#    'shield',
#    'astronaut',
#    'cosmic',
#    'radiation'],
#   ['boiled',
#    'better',
#    'scientist',
#    'say',
#    'confirming',
#    'tea',
#    'drinker',
#    'microwave',
#    'brew'],
#   ['scientist',
#    'discover',
#    'baby',
#    'milky',
#    'way',
#    'billion',
#    'light',
#    'year',
#    'away'],
#   ['transparent', 'solar', 'panel', 'window', 'hit', 'record', 'efficiency'],
#   ['climate',
#    'change',
#    'satellite',
#    'record',
#    'history',
#    'antarctic',
#    'melting'],
#   ['arecibo',
#    'observatory',
#    'report',
#    'damaged',
#    'reflector',
#    'dish',
#    'cable'],
#   ['nasa', 'away', 'harmful', 'nickname', 'cosmic', 'object'],
#   ['smart',
#    'researcher',
#    'find',
#    'new',
#    'way',
#    'make',
#    'bacteria',
#    'sensitive',
#    'antibiotic'],
#   ["china's",
#    'tianwen',
#    'mission',
#    'capture',
#    'unique',
#    'image',
#    'earth',
#    'moon',
#    'way',
#    'mar'],
#   ['spacex',
#    'next',
#    'starship',
#    'start',
#    'take',
#    'shape',
#    'elon',
#    'musk',
#    'talk',
#    'next',
#    'step'],
#   ['astronomer',
#    'peer',
#    'billion',
#    'year',
#    'back',
#    'time',
#    'surprised',
#    'find',
#    'milky',
#    'way',
#    'look',
#    'alike'],
#   ['watch',
#    "spacex's",
#    'stunning',
#    'starship',
#    'prototype',
#    'hop',
#    'test',
#    'flight',
#    'landing'],
#   ["nasa's", 'aqua', 'satellite', 'show', 'two', 'view', 'apple', 'fire'],
#   ['spacex',
#    'launch',
#    'new',
#    'satellite',
#    'controversial',
#    'starlink',
#    'satellite'],
#   ['best', 'place', 'earth', 'see', 'star', 'according', 'science'],
#   ['broken',
#    'cable',
#    'ha',
#    'smashed',
#    'huge',
#    'hole',
#    'arecibo',
#    'observatory'],
#   ["nasa's", 'curiosity', 'rover', 'celebrating', 'year', 'mar', 'bgr'],
#   ['dimming',
#    'one',
#    "galaxy's",
#    'brightest',
#    'star',
#    'caused',
#    'dust',
#    'cloud'],
#   ['altering', 'roundworm', 'protein', 'develop', 'anti', 'aging', 'drug'],
#   ['watch',
#    'hubble',
#    'telescope',
#    'used',
#    'lunar',
#    'eclipse',
#    'detecting',
#    'life',
#    'exoplanets'],
#   ['massive',
#    'sunspot',
#    'turning',
#    'towards',
#    'earth',
#    'may',
#    'affect',
#    'electrical',
#    'system'],
#   ["august's", 'sturgeon', 'moon', 'full', 'moon', 'date'],
#   ['live',
#    'coverage',
#    'ariane',
#    'rocket',
#    'launch',
#    'three',
#    'satellite',
#    'french',
#    'guiana'],
#   ['helium',
#    'structure',
#    'found',
#    'sun',
#    'atmosphere',
#    'nasa',
#    'sounding',
#    'rocket'],
#   ['nasa',
#    'share',
#    'stunning',
#    'photo',
#    'jupiter',
#    'saturn',
#    'rising',
#    'beyond',
#    'alien',
#    'throne',
#    'rock'],
#   ['early',
#    'human',
#    'knew',
#    'make',
#    'comfy',
#    'pest',
#    'free',
#    'bed',
#    'study',
#    'say'],
#   ['marsquakes', 'reveal', 'hidden', 'insight', 'red', 'planet', 'interior'],
#   ['spacex',
#    'hop',
#    'elon',
#    'musk',
#    'pull',
#    'plug',
#    'starship',
#    'test',
#    'flight',
#    'automatic',
#    'abort'],
#   ["nasa's",
#    'insight',
#    'mar',
#    'lander',
#    'reveals',
#    "what's",
#    'inside',
#    'red',
#    'planet'],
#   ['climate',
#    'change',
#    'arctic',
#    'ice',
#    'gone',
#    'summer',
#    'scientist',
#    'warn'],
#   ['perseid', 'meteor', 'shower', 'peak', 'tuesday', 'night', 'watch'],
#   ['next',
#    'nasa',
#    'spacex',
#    'astronaut',
#    'flight',
#    'launch',
#    'earlier',
#    'october'],
#   ['analyst',
#    'find',
#    'new',
#    'electrocatalyst',
#    'convert',
#    'carbon',
#    'dioxide',
#    'liquid',
#    'fuel'],
#   ['exploding', 'star', 'created', 'calcium', 'bone', 'teeth', 'study', 'say'],
#   ['vikram',
#    "sarabhai's",
#    'birth',
#    'anniversary',
#    'isro',
#    'name',
#    'crater',
#    'captured',
#    'chandrayaan'],
#   ['august', 'full', 'sturgeon', 'moon', 'illuminate', 'sky', 'tonight'],
#   ["here's", 'exploding', 'star', 'forged', 'calcium', 'teeth', 'bone'],
#   ['creepy', 'tongue', 'eating', 'vampire', "fish's", 'worst', 'nightmare'],
#   ['healthful', 'milk', 'chocolate', 'adding', 'peanut', 'coffee', 'waste'],
#   ['dinosaur', 'got', 'cancer', 'say', 'scientist'],
#   ['stellar', 'explosion', 'created', 'calcium', 'found', 'teeth', 'bone'],
#   ['artemis',
#    "i's",
#    'sl',
#    'rocket',
#    'core',
#    'stage',
#    'completes',
#    'first',
#    'four',
#    'green',
#    'run',
#    'test'],
#   ['star', 'gazers', 'treated', 'celestial', 'firework', 'show', 'tonight'],
#   ['first',
#    'gene',
#    'edited',
#    'squid',
#    'history',
#    'biological',
#    'breakthrough'],
#   ['gnarly', 'tumour', 'show', 'dinosaur', 'got', 'cancer', 'world', 'news'],
#   ['preserved', 'hell', 'ant', 'ha', 'devouring', 'prey', 'million', 'year'],
#   ['cere',
#    'ocean',
#    'world',
#    'active',
#    'geology',
#    'according',
#    'close',
#    'data',
#    'nasa',
#    'spacecraft',
#    'dawn',
#    'aug',
#    'nz',
#    'international',
#    'news'],
#   ['bite',
#    'mark',
#    'dinosaur',
#    'bone',
#    'present',
#    'evidence',
#    'dinosaur',
#    'eating',
#    'mammal'],
#   ['british',
#    'fossil',
#    'hunter',
#    'find',
#    'bone',
#    'new',
#    'dinosaur',
#    'specie',
#    'cousin',
#    'rex'],
#   ['download', 'nasa', 'new', 'batch', 'stunning', 'image', 'mar', 'free'],
#   ['berocca', 'turn', 'pee', 'bright', 'yellow'],
#   ['easy', 'eating', 'green', 'herbivore', 'extinction', 'risk'],
#   ['science', 'prof', 'real', 'reason', 'razor', 'go', 'dull'],
#   ['cable',
#    'failure',
#    'put',
#    'massive',
#    'hole',
#    'one',
#    'planet',
#    'largest',
#    'telescope'],
#   ['mar', 'mission', 'ero', 'space', 'odyssey'],
#   ['healthy',
#    'blue',
#    'food',
#    'colouring',
#    'could',
#    'soon',
#    'brightening',
#    'dinner',
#    'plate'],
#   ['new',
#    'type',
#    'bacteria',
#    'discovered',
#    'jamaica',
#    'plain',
#    'living',
#    'solar',
#    'panel',
#    'arboretum'],
#   ['researcher', 'find', 'new', 'way', 'detect', 'blood', 'clot'],
#   ['sun',
#    'acting',
#    'weird',
#    'lately',
#    'scientist',
#    'say',
#    'unexplained',
#    'phenomenon',
#    'happening'],
#   ['deciphering', 'natural', 'law', 'molecular', 'mastermind'],
#   ['phylogenetic',
#    'analysis',
#    'reveals',
#    'evolution',
#    'mitochondrial',
#    'calcium',
#    'transporter'],
#   ['moon',
#    'saturn',
#    'jupiter',
#    'aligning',
#    'tonight',
#    'rare',
#    'chance',
#    'see',
#    'three',
#    'close',
#    'one',
#    'another'],
#   ['save',
#    'restflix',
#    'restful',
#    'sleep',
#    'streaming',
#    'service',
#    'subscription'],
#   ["spacex's",
#    'endeavour',
#    'spacecraft',
#    'successfully',
#    'return',
#    'nasa',
#    'astronaut',
#    'earth'],
#   ['greenland', 'ice', 'melting', 'past', 'tipping', 'point', 'study'],
#   ['live',
#    'tracking',
#    'spacex',
#    'crew',
#    'dragon',
#    'splashdown',
#    'near',
#    'pensacola'],
#   ['thermal', 'displacement', 'marine', 'heatwaves'],
#   ['ultrathin',
#    'flat',
#    'lens',
#    'high',
#    'resolution',
#    'imaging',
#    'using',
#    'monolayer',
#    'transition',
#    'metal'],
#   ['scientist', 'find', 'way', 'turn', 'disposed', 'ppe', 'biofuel'],
#   ['ucsf', 'study', 'sf', 'firefighter', 'coronavirus', 'antibody'],
#   ['houston', "we've", 'problem', 'spoken', 'space'],
#   ['moon', 'sun', 'size', "earth's", 'sky'],
#   ['last',
#    'know',
#    'historic',
#    'reptile',
#    'lived',
#    'kind',
#    'absurdly',
#    'long',
#    'neck'],
#   ["spacex's",
#    'th',
#    'mission',
#    'may',
#    'well',
#    'crack',
#    'remarkable',
#    'reusability',
#    'record'],
#   ['nasa',
#    'go',
#    'woke',
#    'bye',
#    'bye',
#    'eskimo',
#    'nebula',
#    'siamese',
#    'twin',
#    'galaxy'],
#   ['face',
#    'mask',
#    'stop',
#    'droplet',
#    'many',
#    'face',
#    'covering',
#    'ineffective'],
#   ['stunning', 'perseid', 'meteor', 'shower', 'hit', 'peak'],
#   ['information', 'catastrophe', 'consume', 'planet', 'mass'],
#   ['transparent',
#    'solar',
#    'panel',
#    'window',
#    'hit',
#    'new',
#    'efficiency',
#    'record',
#    'could',
#    'help',
#    'enable',
#    'skyscraper',
#    'serve',
#    'power',
#    'source'],
#   ['dark',
#    'matter',
#    'breakthrough',
#    'allows',
#    'probing',
#    'three',
#    'popular',
#    'theory',
#    'time'],
#   ['climate',
#    'change',
#    'satellite',
#    'record',
#    'history',
#    'antarctic',
#    'melting'],
#   ['nasa',
#    'probe',
#    'completes',
#    'final',
#    'practice',
#    'asteroid',
#    'sample',
#    'collection'],
#   ['scientist',
#    'document',
#    'rare',
#    'boomerang',
#    'earthquake',
#    'atlantic',
#    'seafloor',
#    'first',
#    'time',
#    'ever'],
#   ['red',
#    'planet',
#    'mar',
#    'glow',
#    'green',
#    'night',
#    'due',
#    'chemical',
#    'reaction'],
#   ['scientist', 'discover', 'blue', 'whirl', 'fire', 'made', 'three', 'flame'],
#   ['bird',
#    'reptile',
#    'cry',
#    'similar',
#    'tear',
#    'human',
#    'say',
#    'new',
#    'research'],
#   ['mile',
#    'long',
#    'ufo',
#    'seen',
#    'moon',
#    'undeniable',
#    'proof',
#    'claim',
#    'alien',
#    'hunter'],
#   ['bone',
#    'close',
#    'relative',
#    'tyrannosaurus',
#    'rex',
#    'discovered',
#    'isle',
#    'wight'],
#   ['editor', 'choice'],
#   ['solar',
#    'system',
#    'look',
#    'like',
#    'deflated',
#    'croissant',
#    'reveals',
#    'nasa'],
#   ['live',
#    'tracking',
#    'spacex',
#    'crew',
#    'dragon',
#    'splashdown',
#    'near',
#    'pensacola'],
#   ['murder',
#    'hornet',
#    'beware',
#    'scientist',
#    'discovered',
#    'prehistoric',
#    'hell',
#    'ant'],
#   ['eating', 'wa', 'social', 'matter', 'early', 'human'],
#   ['source',
#    'viburnum',
#    'tinus',
#    "plant's",
#    'iridescent',
#    'blue',
#    'fruit',
#    'discovered'],
#   ['nasa',
#    'spacecraft',
#    'get',
#    'look',
#    'one',
#    'strangest',
#    'place',
#    'solar',
#    'system'],
#   ['dwarf',
#    'planet',
#    'cere',
#    'ocean',
#    'world',
#    'salty',
#    'drinking',
#    'water',
#    'deep',
#    'underground'],
#   ['viper',
#    'rover',
#    'use',
#    'thales',
#    'alenia',
#    'space',
#    'tech',
#    'earth',
#    'comms'],
#   ['milky',
#    'way',
#    'like',
#    'baby',
#    'galaxy',
#    'discovered',
#    'million',
#    'billion',
#    'light',
#    'year',
#    'away'],
#   ['mysterious',
#    'fast',
#    'radio',
#    'burst',
#    'detected',
#    'closer',
#    'earth',
#    'ever'],
#   ['quantum',
#    'mechanical',
#    'interaction',
#    'two',
#    'time',
#    'crystal',
#    'ha',
#    'experimentally',
#    'demonstrated'],
#   ['new',
#    'method',
#    'reveals',
#    'dynamic',
#    'cell',
#    'development',
#    'gene',
#    'activity'],
#   ['came',
#    'alive',
#    'astronaut',
#    'recount',
#    'wild',
#    'ride',
#    'home',
#    "spacex's",
#    'crew',
#    'dragon',
#    'jakarta',
#    'post'],
#   ['dinosaur', 'suffered', 'deadly', 'cancer', 'million', 'year', 'ago'],
#   ['watch',
#    "spacex's",
#    'stunning',
#    'starship',
#    'prototype',
#    'hop',
#    'test',
#    'flight',
#    'landing'],
#   ['space', 'brick', 'scientist', 'publish', 'paper', 'making', 'moon'],
#   ['preserved',
#    'ice',
#    'age',
#    'puppy',
#    'apparently',
#    'ate',
#    'woolly',
#    'rhino',
#    'died'],
#   ['palaeontologist',
#    'discover',
#    'new',
#    'specie',
#    'dinosaur',
#    'isle',
#    'wight'],
#   ['crew', 'dragon', 'spacecraft', 'successfully', 'land', 'gulf', 'mexico'],
#   ['katie', 'mack', 'knowing', 'universe', 'end', 'freeing'],
#   ['super', 'speedy', 'acid', 'cloud', 'ha', 'hiding', 'venus', 'decade'],
#   ['entire',
#    'city',
#    'could',
#    'fit',
#    'inside',
#    "moon's",
#    'monstrous',
#    'lava',
#    'tube'],
#   ['spectacular',
#    'photo',
#    "august's",
#    'full',
#    'sturgeon',
#    'moon',
#    'around',
#    'world'],
#   ['demo', 'success', 'keep', 'spacex', 'track', 'tourist', 'flight', 'late'],
#   ['human', 'discover', 'use', 'fire'],
#   ['sign', 'insect', 'apocalypse', 'united', 'state', 'earth', 'com'],
#   ['zombie',
#    'cicada',
#    'lure',
#    'victim',
#    'sex',
#    'passing',
#    'deadly',
#    'parasite'],
#   ['ice', 'cap', "canada's", 'st', "patrick's", 'bay', 'disappeared'],
#   ['physicist',
#    'watch',
#    'quantum',
#    'particle',
#    'tunnel',
#    'solid',
#    'barrier',
#    "here's",
#    'found'],
#   ['universe', 'end', 'according', 'renowned', 'astrophysicist'],
#   ["france's",
#    'covid',
#    'case',
#    'four',
#    'month',
#    'high',
#    'health',
#    'system',
#    'holding'],
#   ['looking', 'column', 'perseid', 'meteor', 'shower', 'back'],
#   ['primate', 'voice', 'box', 'evolving', 'rapid', 'pace'],
#   ['like',
#    'bright',
#    'shooting',
#    'star',
#    'seen',
#    'meteor',
#    'shower',
#    'visible',
#    'part',
#    'ireland'],
#   ['nasa',
#    'find',
#    'intriguing',
#    'evidence',
#    'alien',
#    'life',
#    'distant',
#    'space',
#    'body'],
#   ['astronomer',
#    'sink',
#    'teeth',
#    'special',
#    'supernova',
#    'exploding',
#    'star',
#    'produce',
#    'calcium',
#    'bone',
#    'teeth'],
#   ['tear',
#    'bird',
#    'reptile',
#    'much',
#    'different',
#    'human',
#    'tear',
#    'say',
#    'scientist'],
#   ['astronomer', 'apply', 'ai', 'discover', 'classify', 'galaxy'],
#   ['tracking',
#    'humanity',
#    'latest',
#    'plastic',
#    'chemical',
#    'toxin',
#    'stranded',
#    'whale',
#    'dolphin'],
#   ['researcher',
#    'one',
#    'step',
#    'closer',
#    'bomb',
#    'sniffing',
#    'cyborg',
#    'locust'],
#   ['candice',
#    'lerae',
#    'johnny',
#    'gargano',
#    'invite',
#    'nxt',
#    'universe',
#    'home'],
#   ['watch',
#    'spacecraft',
#    'leave',
#    'international',
#    'space',
#    'station',
#    'live',
#    'online',
#    'tuesday'],
#   ['glacier',
#    'could',
#    'sculpted',
#    'mar',
#    'valley',
#    'study',
#    'jakarta',
#    'post'],
#   ['barbaric', 'horse', 'killing', 'put', 'french', 'countryside', 'alert'],
#   ['saturn',
#    'jupiter',
#    'moon',
#    'align',
#    'netizens',
#    'flood',
#    'internet',
#    'mesmerizing',
#    'picture',
#    'night',
#    'hindustan',
#    'time'],
#   ['spacex',
#    'abort',
#    "starship's",
#    'hop',
#    'test',
#    'another',
#    'attempt',
#    'may',
#    'happen',
#    'today'],
#   ['ancient',
#    'human',
#    'extremely',
#    'complicated',
#    'sex',
#    'love',
#    'evidence',
#    'show'],
#   ['human',
#    'prepared',
#    'bed',
#    'sleep',
#    'right',
#    'dawn',
#    'specie',
#    'year',
#    'ago'],
#   ['nasa', 'map', 'beirut', 'blast', 'damage', 'high', 'precision', 'image'],
#   ['arecibo',
#    'observatory',
#    'data',
#    'help',
#    'lead',
#    'discovery',
#    'cosmic',
#    'heartbeat'],
#   ['perseid',
#    'meteor',
#    'shower',
#    'fireball',
#    'soar',
#    'across',
#    'sky',
#    'ireland',
#    'dozen',
#    'fly',
#    'uk'],
#   ['dimming',
#    'one',
#    "galaxy's",
#    'brightest',
#    'star',
#    'caused',
#    'dust',
#    'cloud'],
#   ['chemical',
#    'signal',
#    'locust',
#    'swarming',
#    'identified',
#    'step',
#    'toward',
#    'curbing',
#    'plague'],
#   ['perseid', 'meteor', 'shower', 'peak', 'date', 'fireball', 'oceanside'],
#   ['elon',
#    'musk',
#    'say',
#    'first',
#    'test',
#    'starship',
#    'make',
#    'hope',
#    'mar',
#    'trip',
#    'look',
#    'real'],
#   ['moon',
#    'star',
#    'compass',
#    'nocturnal',
#    'animal',
#    'light',
#    'pollution',
#    'leading',
#    'astray'],
#   ['ancient', 'mar', 'may', 'le', 'wet', 'thought'],
#   ['exploding',
#    'black',
#    'dwarf',
#    'could',
#    'last',
#    'interesting',
#    'thing',
#    'happen',
#    'universe'],
#   ['nasa', 'te', 'find', 'new', 'exoplanets', 'candidate'],
#   ["nasa's",
#    'exoplanet',
#    'hunter',
#    'finished',
#    'mission',
#    'going',
#    'anywhere'],
#   ['like',
#    'weather',
#    'epidemiologist',
#    'responds',
#    'predicted',
#    'peak',
#    'leak'],
#   ['stellar', 'pulsation', 'distribute', 'key', 'ingredient', 'life'],
#   ['million', 'year', 'old', 'microbe', 'brought', 'back', 'life'],
#   ['scientist',
#    'discover',
#    'planet',
#    'scale',
#    'wall',
#    'poisonous',
#    'cloud',
#    'moving',
#    'across',
#    'venus'],
#   ['scientist', 'captured', 'ultimate', 'selfie', 'earth'],
#   ['energy', 'efficient', 'tuning', 'spintronic', 'neuron'],
#   ['new', 'guinea', 'island', 'greatest', 'plant', 'diversity', 'world'],
#   ['barbaric', 'horse', 'killing', 'put', 'french', 'countryside', 'alert'],
#   ['wish', 'could', 'fly', 'free', 'like', 'beautiful', 'space', 'butterfly'],
#   ['electric',
#    'cooker',
#    'easy',
#    'efficient',
#    'way',
#    'sanitize',
#    'n',
#    'mask',
#    'study',
#    'find'],
#   ['researcher', 'study', 'science', 'behind', 'staying', 'motivated'],
#   ['new', 'study', 'reveals', 'lower', 'energy', 'limit', 'life', 'earth'],
#   ['microbe', 'starter', 'culture', 'make', 'fermented', 'sausage', 'tasty'],
#   ['iconic', 'arecibo', 'telescope', 'go', 'quiet', 'major', 'damage'],
#   ['see', 'mar', 'moon', 'align', 'weekend'],
#   ['friendly',
#    'shark',
#    'new',
#    'study',
#    'show',
#    'also',
#    'make',
#    'friend',
#    'shark'],
#   ['nanocellulose', 'gold'],
#   ['disrupting', 'sicilian', 'mafia', 'social', 'network', 'analysis'],
#   ['dwarf', 'planet', 'cere', 'ocean', 'world', 'study'],
#   ['nasa',
#    'first',
#    'asteroid',
#    'sampling',
#    'spacecraft',
#    'set',
#    'collect',
#    'sample',
#    'bennu',
#    'asteroid'],
#   ['spacex', 'forced', 'abort', 'starship', 'jump'],
#   ['scientist',
#    'determine',
#    'oumuamua',
#    'made',
#    'molecular',
#    'hydrogen',
#    'ice'],
#   ['discovery',
#    'transforms',
#    'understanding',
#    'hydrogen',
#    'depletion',
#    'seafloor'],
#   ['nasa',
#    'sounding',
#    'rocket',
#    'discovered',
#    'helium',
#    'structure',
#    'solar',
#    'corona'],
#   ['scientist',
#    'found',
#    'year',
#    'old',
#    'human',
#    'bed',
#    'made',
#    'grass',
#    'ash'],
#   ['galaxy',
#    'suspiciously',
#    'similar',
#    'milky',
#    'way',
#    'ha',
#    'spotted',
#    'early',
#    'universe'],
#   ['mar',
#    'moon',
#    'earth',
#    'aligned',
#    'dawn',
#    'north',
#    'american',
#    'could',
#    'see',
#    'without',
#    'telescope'],
#   ['composite', 'launch', 'mar'],
#   ['nasa',
#    'get',
#    'woke',
#    'racist',
#    'star',
#    'name',
#    'change',
#    'new',
#    'hq',
#    'name'],
#   ['st',
#    'francis',
#    "xavier's",
#    'college',
#    'student',
#    'test',
#    'positive',
#    'school',
#    'closed'],
#   ['oldest', 'human', 'cremation', 'near', 'east', 'unearthed'],
#   ['multifocal',
#    'contact',
#    'lens',
#    'slow',
#    'progression',
#    'nearsightedness',
#    'child'],
#   ['exploding',
#    'black',
#    'dwarf',
#    'could',
#    'last',
#    'interesting',
#    'thing',
#    'happen',
#    'universe'],
#   ['fastest',
#    'ever',
#    'star',
#    'discovered',
#    'orbiting',
#    'milky',
#    "way's",
#    'supermassive',
#    'black',
#    'hole'],
#   ['star', 'rich', 'phosphorus', 'seed', 'life', 'universe', 'astrobiology'],
#   ['terror',
#    'crocodile',
#    'dimension',
#    'bus',
#    'fed',
#    'dinosaur',
#    'examine',
#    'say'],
#   ['explore',
#    'outdoors',
#    'great',
#    'opportunity',
#    'view',
#    'planet',
#    'crescent',
#    'moon',
#    'constellation',
#    'new',
#    'hampshire'],
#   ['ootw',
#    'space',
#    'nasa',
#    'discovers',
#    'salty',
#    'lake',
#    'cere',
#    'ice',
#    'crust'],
#   ["nasa's",
#    'ingenuity',
#    'mar',
#    'helicopter',
#    'recharges',
#    'battery',
#    'flight'],
#   ['adding',
#    'peanut',
#    'skin',
#    'milk',
#    'chocolate',
#    'make',
#    'healthier',
#    'suggests',
#    'study'],
#   ['innovation',
#    'scientist',
#    'find',
#    'way',
#    'extract',
#    'store',
#    'co',
#    'vehicle',
#    'exhaust'],
#   ['gamma',
#    'ray',
#    'heartbeat',
#    'gas',
#    'cloud',
#    'powered',
#    'black',
#    'hole',
#    'baffling'],
#   ['earth',
#    'wa',
#    'home',
#    'terror',
#    'crocodile',
#    'nearly',
#    'size',
#    'city',
#    'bus'],
#   ['young',
#    'galaxy',
#    'look',
#    'like',
#    'milky',
#    'way',
#    'spotted',
#    'scientist',
#    'looking',
#    'back',
#    'time',
#    'early',
#    'universe'],
#   ['nasa',
#    'te',
#    'space',
#    'agency',
#    'planet',
#    'hunter',
#    'completes',
#    'primary',
#    'mission',
#    'roaring',
#    'success'],
#   ['world',
#    'smallest',
#    'dinosaur',
#    'inch',
#    'creature',
#    'likely',
#    'lizard',
#    'instead'],
#   ['melbourne',
#    'recovers',
#    'regional',
#    'victoria',
#    'struggling',
#    'coronacast'],
#   ['closest',
#    'ever',
#    'mysterious',
#    'fast',
#    'radio',
#    'burst',
#    'found',
#    'light',
#    'year',
#    'earth'],
#   ['ride',
#    'shotgun',
#    "nasa's",
#    'osiris',
#    'rex',
#    'asteroid',
#    'probe',
#    'buzz',
#    'bennu',
#    'video'],
#   ['spacex',
#    'crew',
#    'dragon',
#    'return',
#    'two',
#    'nasa',
#    'astronaut',
#    'sentinelassam'],
#   ['bird',
#    'reptile',
#    'cry',
#    'similar',
#    'tear',
#    'human',
#    'say',
#    'new',
#    'research'],
#   ['renowned',
#    'climate',
#    'scientist',
#    'konrad',
#    'steffen',
#    'dy',
#    'falling',
#    'ice',
#    'greenland'],
#   ['national', 'anti', 'doping', 'center', 'appears', 'kyrgyzstan'],
#   ['team',
#    'international',
#    'physicist',
#    'join',
#    'force',
#    'hunt',
#    'sterile',
#    'neutrino'],
#   ['humanity', 'worry', 'digital', 'apocalypse'],
#   ['relive', 'final', 'descent', "spacex's", 'crew', 'dragon', 'spacecraft'],
#   ['celebrate',
#    'mar',
#    'reconnaissance',
#    'orbiter',
#    'th',
#    'birthday',
#    'view',
#    'mar'],
#   ['physicist',
#    'predicts',
#    'mindboggling',
#    'number',
#    'year',
#    'universe',
#    'end'],
#   ['see', 'face', 'everywhere', 'look'],
#   ['blue',
#    'moon',
#    'catch',
#    'halloween',
#    'blue',
#    'moon',
#    'year',
#    'happens',
#    'every',
#    'year'],
#   ['nasa',
#    'establishes',
#    'board',
#    'initially',
#    'review',
#    'mar',
#    'sample',
#    'return',
#    'plan'],
#   ['herbivore', 'predator', 'risk', 'extinction'],
#   ['quantum', 'material', 'quest', 'could', 'benefit', 'graphene', 'buckle'],
#   ['spacex', 'brings', 'nasa', 'astronaut', 'safely', 'home', 'milestone'],
#   ['toxicant',
#    'whale',
#    'dolphin',
#    'traced',
#    'back',
#    'fossil',
#    'fuel',
#    'single',
#    'use',
#    'plastic'],
#   ['huge',
#    'sunspot',
#    'turning',
#    'towards',
#    'earth',
#    'may',
#    'hit',
#    'gps',
#    'radio',
#    'communication',
#    'detail'],
#   ['nasa',
#    'shot',
#    'laser',
#    'moon',
#    'orbiter',
#    'one',
#    'finally',
#    'bounced',
#    'back'],
#   ['first', 'person', 'evolve'],
#   ['rare',
#    'boomerang',
#    'earthquake',
#    'detected',
#    'atlantic',
#    'ocean',
#    'first',
#    'time'],
#   ['year', 'myth', 'stone', 'age', 'man', 'finally', 'put', 'bed'],
#   ['shark',
#    'mystery',
#    'monster',
#    'devoured',
#    'ft',
#    'great',
#    'white',
#    'exposed',
#    'super',
#    'predator',
#    'hunt'],
#   ['arecibo', 'radio', 'observatory', 'damaged'],
#   ['japan',
#    'turn',
#    'eye',
#    'sky',
#    'race',
#    'make',
#    'flying',
#    'car',
#    'reality',
#    'three',
#    'year'],
#   ['jeff',
#    'bezos',
#    'elon',
#    "musk's",
#    'plan',
#    'colonize',
#    'space',
#    'even',
#    'crazier',
#    'thought'],
#   ['science',
#    'news',
#    'roundup',
#    'stem',
#    'cell',
#    'give',
#    'hope',
#    'revival',
#    'extinct',
#    'rhino',
#    'british',
#    'fossil',
#    'hunter',
#    'find',
#    'bone',
#    'new',
#    'dinosaur',
#    'specie'],
#   ['stellar',
#    'pulsation',
#    'distribute',
#    'key',
#    'ingredient',
#    'life',
#    'astrobiology'],
#   ['picture', 'damaged', 'home', 'shattered', 'dream', 'beirut'],
#   ['scientist',
#    'win',
#    'grant',
#    'study',
#    "brain's",
#    'role',
#    'tracking',
#    'odor'],
#   ['spacex', 'deserves', 'celebrated'],
#   ['face', 'mask', 'garbage', 'could', 'make', 'great', 'biofuel'],
#   ['space',
#    'x',
#    'splashdown',
#    'elon',
#    'musk',
#    'say',
#    'religious',
#    'prayed',
#    'one',
#    'astronaut',
#    'return',
#    'ear'],
#   ['experimental',
#    'result',
#    'reveal',
#    'disintegration',
#    'higgs',
#    'boson',
#    'muon'],
#   ['zombie',
#    'cicada',
#    'spotted',
#    'united',
#    'state',
#    "we're",
#    'officially',
#    'creeped'],
#   ['prehistoric',
#    'hell',
#    'ant',
#    'stuck',
#    'amber',
#    'ha',
#    'mauling',
#    'prey',
#    'million',
#    'year'],
#   ["nature's", 'resilient', 'like', 'think', 'warns', 'irish', 'expert'],
#   ['new',
#    'study',
#    'suggests',
#    'covid',
#    'case',
#    'ontario',
#    'much',
#    'higher',
#    'reported'],
#   ['mar', 'eerie', 'pulsing', 'nightglow'],
#   ['alien',
#    'life',
#    'bombshell',
#    'scientist',
#    'say',
#    'find',
#    'intelligent',
#    'life',
#    'within',
#    'lifetime'],
#   ['crocodile', 'tear', 'surprisingly', 'similar'],
#   ['climate', 'change', 'scientist', 'dead', 'falling', 'crevasse'],
#   ['pest', 'controller', 'find', 'wasp', 'nest', 'size', 'space', 'hopper'],
#   ['thousand',
#    'earthlike',
#    'blanets',
#    'might',
#    'circle',
#    'milky',
#    "way's",
#    'central',
#    'black',
#    'hole'],
#   ['astronomer',
#    'establish',
#    'saturn',
#    'like',
#    'exoplanet',
#    'utilizing',
#    'innovative',
#    'strategy'],
#   ["world's",
#    'tiniest',
#    'dinosaur',
#    'actually',
#    'lizard',
#    'scientist',
#    'admit',
#    'retracting',
#    'study'],
#   ['global',
#    'warming',
#    'could',
#    'unlock',
#    'even',
#    'carbon',
#    'tropical',
#    'soil'],
#   ['massive',
#    'wall',
#    'acid',
#    'cloud',
#    'stretching',
#    'mile',
#    'found',
#    'hiding',
#    'venus',
#    'year'],
#   ['yellowstone',
#    'volcano',
#    'eruption',
#    'tracker',
#    'many',
#    'time',
#    'ha',
#    'yellowstone',
#    'erupted',
#    'mapped'],
#   ['violent',
#    'thunderstorm',
#    'jupiter',
#    'may',
#    'form',
#    'mushballs',
#    'fall',
#    'sky'],
#   ['canary',
#    'coal',
#    'mine',
#    'greenland',
#    'ice',
#    'ha',
#    'shrunk',
#    'beyond',
#    'return',
#    'study',
#    'find'],
#   ['sciaps',
#    'helping',
#    'put',
#    'first',
#    'woman',
#    'moon',
#    'recycling',
#    'international'],
#   ['solar', 'system', 'shaped', 'like', 'deflated', 'croissant'],
#   ['long', 'neck', 'helped', 'reptile', 'hunt', 'underwater'],
#   ['watch', 'live', 'today', 'starlink', 'mission', 'set', 'take', 'today'],
#   ['positive',
#    'dielectrophoresis',
#    'based',
#    'raman',
#    'activated',
#    'droplet',
#    'sorting',
#    'culture',
#    'free',
#    'label',
#    'free',
#    'screening',
#    'enzyme',
#    'function',
#    'vivo'],
#   ['cu', 'boulder', 'move', 'begin', 'know'],
#   ['sydney',
#    'treated',
#    'strawberry',
#    'moon',
#    'eclipse',
#    'saturday',
#    'morning'],
#   ['new', 'research', 'show', 'dinosaur', 'suffered', 'malignant', 'cancer'],
#   ['france',
#    'allen',
#    'obituary',
#    'pioneering',
#    'computer',
#    'scientist',
#    'dy',
#    "alzheimer's",
#    'disease'],
#   ['end', 'universe', 'universe', 'die', 'according', 'physicist'],
#   ['spacex', 'completes', 'test', 'flight', 'mar', 'rocket', 'prototype'],
#   ['nasa',
#    'tiny',
#    'ingenuity',
#    'mar',
#    'helicopter',
#    'hit',
#    'first',
#    'space',
#    'milestone'],
#   ['nasa',
#    'probe',
#    'spot',
#    'martian',
#    'night',
#    'sky',
#    'pulsing',
#    'uv',
#    'light',
#    'sentinelassam'],
#   ['black', 'hole', 'fails', 'job'],
#   ['dwarf', 'planet', 'cere', 'ocean', 'world', 'study', 'jakarta', 'post'],
#   ['stunning',
#    'image',
#    'red',
#    'planet',
#    'captured',
#    'mar',
#    'reconnaissance',
#    'orbiter'],
#   ['laser', 'beam', 'reflected', 'earth', 'moon', 'boost', 'science'],
#   ['dinosaur', 'got', 'cancer', 'say', 'scientist', 'article'],
#   ['astronomer', 'kill', 'fun', 'blame', 'dust', 'betelgeuse', 'dimming'],
#   ['nasa',
#    'astronaut',
#    'make',
#    'historic',
#    'return',
#    'earth',
#    'aboard',
#    'spacex',
#    'capsule'],
#   ['surface',
#    'mar',
#    'show',
#    'scar',
#    'glacier',
#    'like',
#    "canada's",
#    'high',
#    'arctic',
#    'study',
#    'find'],
#   ['hair', 'strand', 'make', 'razor', 'blade', 'chip', 'crack'],
#   ['weather', 'ok', 'spacex', 'starlink', 'launch', 'cape', 'canaveral'],
#   ['even',
#    'dinosaur',
#    'frightened',
#    'ancient',
#    'creature',
#    'roaming',
#    "earth's"],
#   ['spacex',
#    'starlink',
#    'satellite',
#    'visible',
#    'week',
#    "here's",
#    'catch',
#    'glimpse'],
#   ['arecibo',
#    'observatory',
#    'puerto',
#    'rico',
#    'suffers',
#    'serious',
#    'damage',
#    'cable',
#    'break'],
#   ['making', 'sense', 'one', 'baffling', 'animal', 'ever', 'lived'],
#   ['new',
#    'kind',
#    'higgs',
#    'boson',
#    'event',
#    'detected',
#    'large',
#    'hadron',
#    'collider'],
#   ['came',
#    'alive',
#    'nasa',
#    'spacex',
#    'dragon',
#    'astronaut',
#    'recount',
#    'thrilling',
#    'return',
#    'earth',
#    'surprising',
#    'zero',
#    'altitude',
#    'splashdown'],
#   ['ghostly', 'blue', 'whirl', 'spinning', 'light', 'made', 'three', 'flame'],
#   ['fifteen', 'year', "nasa's", 'mar', 'reconnaissance', 'orbiter', 'picture'],
#   ['nasa',
#    'juno',
#    'craft',
#    'ha',
#    'found',
#    'weird',
#    'stuff',
#    'jupiter',
#    'atmosphere'],
#   ['green',
#    'road',
#    'revolution',
#    'adding',
#    'pollution',
#    'risk',
#    'childhood',
#    'asthma'],
#   ['watch',
#    'spacex',
#    'stunning',
#    'starship',
#    'prototype',
#    'hop',
#    'test',
#    'flight',
#    'landing'],
#   ['learned', 'new', 'dinosaur', 'related', 'tyrannosaurus', 'rex'],
#   ['new', 'specie', 'dinosaur', 'discovered', 'isle', 'wight'],
#   ['biotechnological', 'production', 'natural', 'antibiotic'],
#   ['nasa',
#    'stereo',
#    "spacecraft's",
#    'lone',
#    'see',
#    'betelgeuse',
#    'reveals',
#    'bizarre',
#    'conduct',
#    'supernova',
#    'imminent'],
#   ['last',
#    'great',
#    'light',
#    'show',
#    'ancient',
#    'iron',
#    'black',
#    'dwarf',
#    'blow',
#    'universe'],
#   ['time', 'camera', 'generates', 'image', 'echo', 'light'],
#   ['space', 'mining', 'around', 'corner'],
#   ['musk', 'read', 'spacex', 'crew', 'dragon', 'return'],
#   ['two',
#    'canadian',
#    'arctic',
#    'ice',
#    'cap',
#    'completely',
#    'disappeared',
#    'satellite',
#    'imagery',
#    'show'],
#   ['deep', 'giant', 'cloud', 'disruption', 'found', 'venus'],
# ...
#   ['domestic',
#    'violence',
#    'killing',
#    'karen',
#    'anne',
#    'ruddelle',
#    'sentenced',
#    'home',
#    'detention'],
#   ['pranab',
#    'mukherjee',
#    'responding',
#    'treatment',
#    'believe',
#    'back',
#    'soon',
#    'son'],
#   ['coronavirus',
#    'uk',
#    'crowd',
#    'pack',
#    'beer',
#    'garden',
#    'day',
#    'high',
#    'temperature'],
#   ['released',
#    'prisoner',
#    'accused',
#    'raping',
#    'killing',
#    'virginia',
#    'woman',
#    'ha',
#    'died'],
#   ['travelled',
#    'five',
#    'state',
#    'border',
#    'middle',
#    'pandemic',
#    'experienced',
#    'may',
#    'shock'],
#   ['clare',
#    'direct',
#    'provision',
#    'resident',
#    'desperate',
#    'situation',
#    'considering',
#    'hunger',
#    'strike'],
#   ['cci',
#    'decides',
#    'transfer',
#    'nchd',
#    'becs',
#    'school',
#    'teacher',
#    'province'],
#   ['pm', 'play', 'incitement', 'call', 'left'],
#   ['brother',
#    'killer',
#    'metropolitan',
#    'police',
#    'officer',
#    'speaks',
#    'amid',
#    'violent',
#    'crime',
#    'surge',
#    'lockdown',
#    'eas'],
#   ['goldstein', 'covid', 'dump', 'ontario', 'ocean', 'red', 'ink'],
#   ['canso',
#    'causeway',
#    'shut',
#    'hour',
#    'sunday',
#    'honour',
#    'chantel',
#    'moore',
#    'mmiwg'],
#   ['canberra',
#    'liberal',
#    'candidate',
#    'peter',
#    'mckay',
#    'condemned',
#    'welcome',
#    'country',
#    'ceremony',
#    'parliamentary',
#    'submission'],
#   ['new',
#    'u',
#    'ambassador',
#    'tanzania',
#    'finally',
#    'start',
#    'tour',
#    'duty',
#    'read',
#    'skip'],
#   ['one',
#    "wellington's",
#    'important',
#    'future',
#    'building',
#    'convention',
#    'exhibition',
#    'centre',
#    'officially',
#    'named',
#    'kina'],
#   ['explained',
#    'behind',
#    'pm',
#    'modi',
#    'three',
#    'big',
#    'digital',
#    'announcement'],
#   ['charity',
#    'register',
#    'lobbyist',
#    'lay',
#    'staff',
#    'looking',
#    'sell',
#    'real',
#    'estate'],
#   ['pm',
#    "modi's",
#    'cowardice',
#    'allowed',
#    'china',
#    'take',
#    "india's",
#    'land',
#    'lie',
#    'ensure',
#    'keep',
#    'rahul',
#    'gandhi'],
#   ['ongwediva', 'inaugurates', 'new', 'junior', 'council'],
#   ['earthquake', 'north', 'carolina', 'strongest', 'area', 'since'],
#   ['ogun',
#    'pdp',
#    'faction',
#    'reconcile',
#    'sikirulai',
#    'others',
#    'meet',
#    'nwc'],
#   ['coronavirus',
#    'spread',
#    'georgia',
#    'widespread',
#    'expanding',
#    'say',
#    'report',
#    'leaked',
#    'wh',
#    'warning'],
#   ['complaint',
#    'sushant',
#    'singh',
#    "rajput's",
#    'death',
#    'politically',
#    'motivated',
#    'maharashtra',
#    'top',
#    'court'],
#   ['nda', 'screening', 'test', 'hold', 'aug', 'registrar'],
#   ['python', 'missing', 'week', 'victoria', 'found'],
#   ['atiku', 'odili', "na'abba", 'political', 'career', 'obasanjo', 'killed'],
#   ['new',
#    'voter',
#    'register',
#    'credible',
#    'despite',
#    'minor',
#    'foreign',
#    'registering',
#    'ec',
#    'insists'],
#   ['police',
#    'still',
#    'investigate',
#    'cause',
#    'deadly',
#    'accident',
#    'cipali',
#    'toll',
#    'road'],
#   ['mobile',
#    'money',
#    'vendor',
#    'shot',
#    'dead',
#    'techiman',
#    'refusing',
#    'hand',
#    'sale'],
#   ['n',
#    'l',
#    'top',
#    'doctor',
#    'say',
#    'travel',
#    'ban',
#    'measure',
#    'helped',
#    'stem',
#    'covid',
#    'spread'],
#   ['tanzania',
#    'public',
#    'urged',
#    'monitor',
#    'water',
#    'project',
#    'implementation'],
#   ['sushant',
#    'singh',
#    "rajput's",
#    'death',
#    'personal',
#    'attack',
#    'made',
#    'aaditya',
#    'thackeray'],
#   ['yr',
#    'old',
#    'kerala',
#    'allegedly',
#    'killed',
#    'brother',
#    'poisoned',
#    'ice',
#    'cream'],
#   ['ghana', 'independence', 'wa', 'one', 'man', 'show', 'oquaye'],
#   ['went',
#    'ram',
#    'janmabhoomi',
#    'send',
#    'message',
#    'muslim',
#    'say',
#    'babri',
#    'litigant',
#    'iqbal',
#    'ansari'],
#   ['manyanya',
#    'advises',
#    'sido',
#    'assist',
#    'importer',
#    'packaging',
#    'material'],
#   ['pdp', 'bot', 'chairman', 'seek', 'conduct', 'lg', 'election', 'inec'],
#   ['auckland',
#    'airport',
#    'reveals',
#    'new',
#    'safe',
#    'zone',
#    'international',
#    'terminal',
#    'anticipation',
#    'pacific',
#    'bubble'],
#   ['bbc',
#    'presenter',
#    'left',
#    'red',
#    'faced',
#    "he's",
#    'forced',
#    'delete',
#    'tweet',
#    'shaming',
#    'tory'],
#   ['drakensberg',
#    'resort',
#    'staff',
#    'lose',
#    'everything',
#    'fire',
#    'injisuthi',
#    'camp'],
#   ['ethiopia', 'abiy', 'stuns', 'nation', 'beloved', 'project', 'call'],
#   ['tanzania', 'pccb', 'question', 'mbowe', 'chadema', 'mp', 'pay', 'cut'],
#   ['symbol',
#    'national',
#    'integration',
#    'top',
#    'leader',
#    'pay',
#    'tribute',
#    'rahat',
#    'indori'],
#   ['parliament', 'approves', 'request', 'securitize', 'gold', 'royalty'],
#   ['indonesia', 'report', 'new', 'coronavirus', 'case', 'death'],
#   ['breaking',
#    'billion',
#    'loan',
#    'rep',
#    'forced',
#    'minute',
#    'break',
#    'heated',
#    'argument',
#    'ameachi'],
#   ['four',
#    'killed',
#    "ireland's",
#    'road',
#    'last',
#    'bank',
#    'holiday',
#    'weekend',
#    'motorist',
#    'stopped',
#    'suspected',
#    'drink',
#    'driving'],
#   ['final',
#    'year',
#    'exam',
#    'himachal',
#    'pradesh',
#    'hc',
#    'put',
#    'stay',
#    'ugc',
#    'exam',
#    'supreme',
#    'court',
#    'order'],
#   ['reduced',
#    'sentence',
#    'guilty',
#    'plea',
#    'could',
#    'end',
#    'bang',
#    'right',
#    'criminal'],
#   ['police', 'tightlipped', 'nab', 'office', 'clash'],
#   ['killed', 'woolly', 'rhino'],
#   ['woman', 'girl', 'hit', 'greatest', 'coronavirus', 'npc'],
#   ['nova',
#    'scotia',
#    'premier',
#    'stephen',
#    'mcneil',
#    'step',
#    'year',
#    'politics'],
#   ['sa',
#    'bank',
#    'provide',
#    'r',
#    'bn',
#    'financial',
#    'lifeline',
#    'ease',
#    'pain',
#    'lockdown'],
#   ['keb', 'raise', 'concern', 'high', 'level', 'aflatoxin', 'maize'],
#   ['asda',
#    'issue',
#    'new',
#    'face',
#    'mask',
#    'rule',
#    'statement',
#    'complaint',
#    'shopper'],
#   ['three',
#    'tour',
#    'company',
#    'banned',
#    'maasai',
#    'mara',
#    'game',
#    'reserve',
#    'flouting',
#    'park',
#    'rule'],
#   ['tasmac', 'outlet', 'reopen', 'tomorrow', 'four', 'month', 'chennai'],
#   ['need',
#    'change',
#    'leadership',
#    'punjab',
#    'congress',
#    'mp',
#    'attack',
#    'cm',
#    'amarinder',
#    'singh',
#    'hooch',
#    'tragedy'],
#   ['northland', 'auckland', 'set', 'hit', 'deluge', 'rain'],
#   ['miner',
#    'became',
#    'overnight',
#    'millionaire',
#    'digging',
#    'huge',
#    'gemstone',
#    'brings',
#    'fortune',
#    'million',
#    'selling',
#    'another',
#    'find'],
#   ['covid',
#    'coronavirus',
#    'auckland',
#    'principal',
#    'student',
#    'school',
#    'level',
#    'put',
#    'community',
#    'risk'],
#   ['coronavirus',
#    'local',
#    'contact',
#    'tracer',
#    'successful',
#    'call',
#    'centre',
#    'online'],
#   ['ghana', 'locked', 'shop', 'nigerian', 'trader'],
#   ['zimbabwe', 'police', 'fret', 'curfew', 'breaker'],
#   ['nsw',
#    'premier',
#    'gladys',
#    'berejiklian',
#    'back',
#    'treasurer',
#    'dominic',
#    'perrottet',
#    'icare',
#    'scandal'],
#   ['ecowas', 'bank', 'support', 'member', 'state', 'almost', 'billion'],
#   ['pm',
#    'modi',
#    'make',
#    'another',
#    'record',
#    'becomes',
#    'longest',
#    'serving',
#    'indian',
#    'prime',
#    'minister',
#    'non',
#    'congress',
#    'origin'],
#   ['knifeman',
#    'killed',
#    'arsenal',
#    'fan',
#    'tube',
#    'station',
#    'face',
#    'life',
#    'jail'],
#   ["they've",
#    'turned',
#    'everyone',
#    'criminal',
#    'say',
#    'owner',
#    'speakeasy',
#    'booze',
#    'ban'],
#   ['heartbreaking',
#    'day',
#    'ahead',
#    "victoria's",
#    'covid',
#    'death',
#    'rate',
#    'triple'],
#   ['lagos', 'ibadan', 'rail', 'commence', 'operation', 'september'],
#   ['parliament', 'approves', 'suspension', 'fiscal', 'rule'],
#   ['dewan',
#    'rakyat',
#    'focus',
#    "sarawak's",
#    'oil',
#    'gas',
#    'right',
#    'claim',
#    'today'],
#   ['tanzanian', 'urged', 'increase', 'consumption', 'meat', 'milk'],
#   ['spice',
#    'right',
#    'indonesian',
#    'startup',
#    'eye',
#    'value',
#    'vanilla',
#    'jakarta',
#    'post'],
#   ['pbdsb',
#    'reinstated',
#    'home',
#    'ministry',
#    'supreme',
#    'council',
#    'meet',
#    'soon'],
#   ['dead', 'fire', 'break', 'covid', 'hospital', 'ahmedabad'],
#   ['voter',
#    'registration',
#    'oti',
#    'region',
#    'top',
#    'ghana',
#    'card',
#    'use',
#    'ec'],
#   ['tuesday'],
#   ['tanzania', 'ruling', 'bail', 'person', 'facing', 'capital', 'offence'],
#   ['bawumia',
#    'open',
#    'conference',
#    'determine',
#    'smartest',
#    'policy',
#    'prosperous',
#    'future'],
#   ['health',
#    'official',
#    'ramp',
#    'effort',
#    'convince',
#    'public',
#    'vaccine',
#    'decision',
#    'based',
#    'science',
#    'politics'],
#   ['lhc', 'imposes', 'ban', 'polythene', 'bag', 'faisalabad', 'gujranwala'],
#   ['queensland', 'woman', 'charged', 'early', 'release', 'super', 'scam'],
#   ['body',
#    'missing',
#    'woman',
#    'found',
#    'next',
#    'rugby',
#    'club',
#    'disappeared',
#    'eight',
#    'day',
#    'ago'],
#   ['pub',
#    'may',
#    'need',
#    'reopen',
#    'county',
#    'county',
#    'say',
#    "who's",
#    'mike',
#    'ryan'],
#   ['high',
#    'court',
#    'decide',
#    'aug',
#    'sabah',
#    'assembly',
#    'dissolution',
#    'case',
#    'go',
#    'trial'],
#   ['progressive',
#    'challenger',
#    'cori',
#    'bush',
#    'upset',
#    'longtime',
#    'incumbent',
#    'lacy',
#    'clay',
#    'missouri',
#    'dem',
#    'primary'],
#   ['new',
#    'covid',
#    'infection',
#    'singapore',
#    'including',
#    'imported',
#    'case',
#    'community'],
#   ['doh',
#    'ha',
#    'yet',
#    'tell',
#    'people',
#    'tested',
#    'positive',
#    'covid',
#    'say',
#    'gordon'],
#   ['sachin',
#    'pilot',
#    'must',
#    'conversation',
#    'first',
#    'congress',
#    'whether',
#    'rebel',
#    'leader',
#    'return'],
#   ['gop',
#    'convention',
#    'charlotte',
#    'closed',
#    'press',
#    'portion',
#    'livestreamed'],
#   ['glimmer', 'hope'],
#   ['mkhize',
#    'call',
#    'da',
#    'mp',
#    'gwarube',
#    'apologise',
#    'retract',
#    'incorrect',
#    'statement'],
#   ['safm', 'radio', 'show', 'catfished', 'canadian', 'con', 'artist'],
#   ['mahama',
#    'trouble',
#    'group',
#    'mercilessly',
#    'blast',
#    'disrespecting',
#    'chief',
#    'imam',
#    'office'],
#   ['body',
#    'u',
#    'service',
#    'member',
#    'recovered',
#    'assault',
#    'vehicle',
#    'sank',
#    'california'],
#   ['charity',
#    'registered',
#    'lobby',
#    'executive',
#    'tell',
#    'common',
#    'committee'],
#   ["namibia's", 'first', 'lady', 'strike', 'chord', 'youth', 'power', 'point'],
#   ['stonehaven',
#    'crash',
#    'train',
#    'derailed',
#    'landslip',
#    'investigator',
#    'confirm'],
#   ['coronavirus', 'nsw', 'new', 'case', 'covid'],
#   ['zahid', 'pleads', 'guilty', 'amended', 'charge'],
#   ['policeman',
#    'investigated',
#    'leak',
#    'footage',
#    'speeding',
#    'fine',
#    'detail'],
#   ['loader', 'driven', 'pike', 'river', 'survivor', 'recovered'],
#   ['ph',
#    "can't",
#    'afford',
#    'extend',
#    'mecq',
#    'economic',
#    'cost',
#    'pile',
#    'roque'],
#   ['another',
#    'aiims',
#    'doctor',
#    'commits',
#    'suicide',
#    'third',
#    'past',
#    'month'],
#   ['iconic',
#    'somerset',
#    'west',
#    'luxury',
#    'hotel',
#    'latest',
#    'tourism',
#    'casualty'],
#   ['macey',
#    'hero',
#    'bulldog',
#    'chase',
#    'four',
#    'machete',
#    'wielding',
#    'burglar'],
#   ['herman', 'cain', 'funeral', 'abundant', 'life'],
#   ['student',
#    'took',
#    'viral',
#    'photo',
#    'packed',
#    'high',
#    'school',
#    'hallway',
#    'say',
#    'received',
#    'threat'],
#   ['todd',
#    'muller',
#    'reveals',
#    'wa',
#    'blindsided',
#    'mental',
#    'toll',
#    'national',
#    'leadership'],
#   ['home', 'evacuation', 'order', 'massive', 'fire', 'rip', 'la', 'county'],
#   ['coronavirus',
#    'crisis',
#    'wa',
#    'put',
#    'phase',
#    'five',
#    'restriction',
#    'hold',
#    'awaiting',
#    'outcome',
#    'clive',
#    'palmer',
#    'high',
#    'court',
#    'challenge'],
#   ['mp', 'pension', 'law', 'illegal', 'src', 'say'],
#   ['dogara', 'supporter', 'dump', 'pdp', 'apc', 'bogoro'],
#   ['many',
#    'pay',
#    'tribute',
#    'late',
#    'editor',
#    'luv',
#    'nhyira',
#    'fm',
#    'saeed',
#    'ali',
#    'yaqub'],
#   ['quebec', 'report', 'new', 'covid', 'case', 'one', 'death'],
#   ['met',
#    'office',
#    'say',
#    'two',
#    'month',
#    'worth',
#    'rain',
#    'could',
#    'fall',
#    'north',
#    'west',
#    'today',
#    'severe',
#    'thunderstorm',
#    'forecast'],
#   ['sh', 'billion', 'covid', 'cash', 'lie', 'idle', 'cbk', 'vault'],
#   ['millionaire',
#    'actor',
#    'russell',
#    'crowe',
#    'say',
#    'embattled',
#    'premier',
#    'daniel',
#    'andrew',
#    'good',
#    'job'],
#   ['pc',
#    'engaged',
#    'sex',
#    'act',
#    'officer',
#    'police',
#    'station',
#    'get',
#    'final',
#    'warning'],
#   ['motorcyclist',
#    'taken',
#    'hospital',
#    'accident',
#    'car',
#    'along',
#    'lorong',
#    'ah',
#    'soo'],
#   ['anniversary', 'article', 'repeal', 'fear', 'unrest', 'curfew', 'srinagar'],
#   ['business',
#    'group',
#    'launch',
#    'new',
#    'petition',
#    'south',
#    'africa',
#    'lockdown',
#    'calling'],
#   ["kenya's", 'virus', 'case', 'rise', 'test', 'positive'],
#   ['unionbank', 'lazada', 'ph', 'unveil', 'credit', 'card', 'manila', 'time'],
#   ['b',
#    'c',
#    'announces',
#    'new',
#    'covid',
#    'case',
#    'rd',
#    'highest',
#    'single',
#    'day',
#    'jump',
#    'since',
#    'beginning',
#    'pandemic'],
#   ['tema', 'akosombo', 'railway', 'project', 'progress'],
#   ['mingle', 'seasoning', 'score', 'massive', 'million', 'deal', 'cole'],
#   ['covid', 'saskatchewan', 'new', 'case', 'active'],
#   ['federal',
#    'judge',
#    'allows',
#    'new',
#    'campus',
#    'sexual',
#    'assault',
#    'rule',
#    'move',
#    'forward',
#    'thehill'],
#   ['expelled', 'jubilee', 'senator', 'speak'],
#   ['near',
#    'miss',
#    'crane',
#    'collapse',
#    'regent',
#    'park',
#    'missing',
#    'two',
#    'people'],
#   ['ttc',
#    'knew',
#    'missing',
#    'part',
#    'blamed',
#    'line',
#    'derailment',
#    'two',
#    'year'],
#   ['covid',
#    'gym',
#    'yoga',
#    'institute',
#    'open',
#    'today',
#    'safe',
#    'go',
#    'coronavirus',
#    'pandemic'],
#   ['fawad', 'ch', 'welcome', 'use', 'technology', 'court'],
#   ['fg', 'give', 'update', 'pilot', 'sacked', 'air', 'peace'],
#   ['national',
#    'leader',
#    'judith',
#    'collins',
#    'intends',
#    'prove',
#    'ardern',
#    'entirely',
#    'wrong',
#    'parliament',
#    'today'],
#   ['man',
#    'face',
#    'charge',
#    'relation',
#    'invercargill',
#    'night',
#    'n',
#    'day',
#    'robbery'],
#   ['auction',
#    'joh',
#    'flo',
#    'bjelke',
#    'petersen',
#    'belonging',
#    'draw',
#    'thousand',
#    'bid'],
#   ['people', 'infected', 'cholera', 'ethiopia', 'un'],
#   ['zartaj',
#    'gul',
#    'wazir',
#    'fumble',
#    'say',
#    'gen',
#    'zia',
#    'ul',
#    'haq',
#    'wa',
#    'born',
#    'aug'],
#   ['light', 'weekend', 'say', 'eskom'],
#   ['invite',
#    'one',
#    'fourth',
#    'covid',
#    'precaution',
#    'place',
#    'independence',
#    'day',
#    'event',
#    'red',
#    'fort'],
#   ['ap',
#    'hospital',
#    'admit',
#    'people',
#    'fever',
#    'breathlessness',
#    'even',
#    'without',
#    'covid',
#    'test'],
#   ['year', 'old', 'student', 'hang', 'fight'],
#   ['kanye', 'west', 'petition', 'appear', 'ballot', 'iowa', 'thehill'],
#   ['pm', 'saved', 'r', 'bn', 'nation', 'two', 'year', 'faraz'],
#   ['manufacture', 'country', "buhari's", 'aide', 'taunt', 'oyedepo', 'cama'],
#   ['female',
#    'soldier',
#    'raped',
#    'impregnated',
#    'bandit',
#    'appeal',
#    'dismissal'],
#   ['maiden', 'virtual', 'congregation', 'university', 'ghana', 'graduate'],
#   ['namibia', 'seaflower', 'quota', 'extended', 'save', 'job'],
#   ['president',
#    'urge',
#    'ulema',
#    'play',
#    'role',
#    'promoting',
#    'mother',
#    'child',
#    'health'],
#   ['girl',
#    'allegedly',
#    'raped',
#    'burnt',
#    'cigarette',
#    "up's",
#    'gorakhpur',
#    'arrested'],
#   ['uk',
#    'weather',
#    'motorway',
#    'flooded',
#    'thunderstorm',
#    'set',
#    'drench',
#    'part',
#    'britain',
#    'weekend'],
#   ['chief', 'justice', 'dilemma', 'article', 'parliament', 'dissolved'],
#   ...]}

# %%
for name, values in dict_of_topics.items():
    counts = pd.Series(dict_of_topics[name]).value_counts()
    wordcloud= WordCloud(max_words=100, width=400, height=200).generate(str(counts))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.figure(figsize=(20,10))
    # plt.title(dict_of_topics[name])
    plt.show()

# %%
for name, values in dict_of_topics.items():
    blob = TextBlob(str(dict_of_topics[name]))
    pos_df = pd.DataFrame(blob.tags, columns = ['word' , 'pos'])
    pos_df = pos_df.pos.value_counts()[:20]
    pos_df.plot(kind='bar', title=dict_of_topics[name])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-3cb53f2156b4> in <module>
#       1 for name, values in dict_of_topics.items():
#       2     blob = TextBlob(str(dict_of_topics[name]))
# ----> 3     pos_df = pd.DataFrame(blob.tags, columns = ['word' , 'pos'])
#       4     pos_df = pos_df.pos.value_counts()[:20]
#       5     pos_df.plot(kind='bar', title="dict_of_topics[name]" )
#
# ~\anaconda3\envs\learn-env\lib\site-packages\textblob\decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~\anaconda3\envs\learn-env\lib\site-packages\textblob\blob.py in pos_tags(self)
#     497         """
#     498         if isinstance(self, TextBlob):
# --> 499             return [val for sublist in [s.pos_tags for s in self.sentences] for val in sublist]
#     500         else:
#     501             return [(Word(unicode(word), pos_tag=t), unicode(t))
#
# ~\anaconda3\envs\learn-env\lib\site-packages\textblob\blob.py in <listcomp>(.0)
#     497         """
#     498         if isinstance(self, TextBlob):
# --> 499             return [val for sublist in [s.pos_tags for s in self.sentences] for val in sublist]
#     500         else:
#     501             return [(Word(unicode(word), pos_tag=t), unicode(t))
#
# ~\anaconda3\envs\learn-env\lib\site-packages\textblob\decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~\anaconda3\envs\learn-env\lib\site-packages\textblob\blob.py in pos_tags(self)
#     500         else:
#     501             return [(Word(unicode(word), pos_tag=t), unicode(t))
# --> 502                     for word, t in self.pos_tagger.tag(self)
#     503                     if not PUNCTUATION_REGEX.match(unicode(t))]
#     504
#
# ~\anaconda3\envs\learn-env\lib\site-packages\textblob\decorators.py in decorated(*args, **kwargs)
#      33     def decorated(*args, **kwargs):
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\textblob\en\taggers.py in tag(self, text)
#      36             text = tb.TextBlob(text)
#      37
# ---> 38         return nltk.tag.pos_tag(text.tokens)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\nltk\tag\__init__.py in pos_tag(tokens, tagset, lang)
#     159     """
#     160     tagger = _get_tagger(lang)
# --> 161     return _pos_tag(tokens, tagset, tagger, lang)
#     162
#     163
#
# ~\anaconda3\envs\learn-env\lib\site-packages\nltk\tag\__init__.py in _pos_tag(tokens, tagset, tagger, lang)
#     116         )
#     117     else:
# --> 118         tagged_tokens = tagger.tag(tokens)
#     119         if tagset:  # Maps to the specified tagset.
#     120             if lang == "eng":
#
# ~\anaconda3\envs\learn-env\lib\site-packages\nltk\tag\perceptron.py in tag(self, tokens, return_conf, use_tagdict)
#     186             if not tag:
#     187                 features = self._get_features(i, word, context, prev, prev2)
# --> 188                 tag, conf = self.model.predict(features, return_conf)
#     189             output.append((word, tag, conf) if return_conf == True else (word, tag))
#     190
#
# ~\anaconda3\envs\learn-env\lib\site-packages\nltk\tag\perceptron.py in predict(self, features, return_conf)
#      65             weights = self.weights[feat]
#      66             for label, weight in weights.items():
# ---> 67                 scores[label] += value * weight
#      68
#      69         # Do a secondary alphabetic sort, for stability
#
# KeyboardInterrupt:
